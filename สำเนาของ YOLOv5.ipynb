# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

# clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# %cd ..
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16003, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 16003 (delta 21), reused 20 (delta 13), pack-reused 15967
# Receiving objects: 100% (16003/16003), 14.66 MiB | 7.19 MiB/s, done.
# Resolving deltas: 100% (10987/10987), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.9/618.9 kB 25.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.3 MB/s eta 0:00:00
# Setup complete. Using torch 2.0.1+cu118 (Tesla T4)
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/Digital/soccer players.v2-release.yolov5pytorch.zip'

# %%
#chagne current path
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --img 640 --batch 8 --epochs 200 --data coco.yaml --weights yolov5n.pt --cache
# Out:
# train: weights=yolov5n.pt, cfg=, data=coco.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
import zipfile

# %%
# !zip -r "/content/drive/MyDrive/สอน flask/football.zip"  "/content/yolov5/runs/train/exp"
# Out:
#   adding: content/yolov5/runs/train/exp/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/val_batch2_pred.jpg (deflated 14%)
#   adding: content/yolov5/runs/train/exp/F1_curve.png (deflated 9%)
#   adding: content/yolov5/runs/train/exp/val_batch0_labels.jpg (deflated 8%)
#   adding: content/yolov5/runs/train/exp/weights/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/weights/best.pt (deflated 12%)
#   adding: content/yolov5/runs/train/exp/weights/last.pt (deflated 12%)
#   adding: content/yolov5/runs/train/exp/val_batch0_pred.jpg (deflated 7%)
#   adding: content/yolov5/runs/train/exp/val_batch1_labels.jpg (deflated 7%)
#   adding: content/yolov5/runs/train/exp/events.out.tfevents.1696838831.54405b6bbf43.7132.0 (deflated 34%)
#   adding: content/yolov5/runs/train/exp/train_batch0.jpg (deflated 9%)
#   adding: content/yolov5/runs/train/exp/val_batch2_labels.jpg (deflated 15%)
#   adding: content/yolov5/runs/train/exp/results.csv (deflated 83%)
# ...

# %%
# !python val.py --weights '/content/yolov5/runs/train/exp/weights/best.pt' --img 640 --conf 0.6  --data coco.yaml
# Out:
# val: data=/content/yolov5/data/coco.yaml, weights=['/content/yolov5/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.6, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING ⚠️ confidence threshold 0.6 > 0.001 produces invalid results
# YOLOv5 🚀 v7.0-218-g9e97ac3 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 1761871 parameters, 0 gradients, 4.1 GFLOPs
# val: Scanning /content/test/labels.cache... 59 images, 1 backgrounds, 0 corrupt: 100% 59/59 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:02<00:00,  1.31s/it]
#                    all         59        198       0.91      0.653       0.78       0.46
# ...
