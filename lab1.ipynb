# %% [markdown]
# <a href="https://colab.research.google.com/github/draisel147/Digital_Image/blob/main/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
im = cv2.imread('/content/drive/MyDrive/image/chest_xray1.jpeg',1)
cv2_imshow(im)
print(im.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=1206x871 at 0x7FEEBC775780>
# (871, 1206, 3)
